# %% [markdown]
# # Links to Papers, Blogs, and Tutorials

# %% [markdown]
# ## Some Popular Deep Learning Papers
#
# Adit Despande
# *The 9 Deep Learning Papers You Need To Know About*
# [Link](https://adeshpande3.github.io/The-9-Deep-Learning-Papers-You-Need-To-Know-About.html)
#
# **Glorot Initialization**
# Xavier Glorot, Yoshua Bengio (2010)
# *Understanding the difficulty of training deep feedforward neural networks*
# [Link](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf)
#
# **CNNs**
# Alex Krizhevsky, Ilya Sutskever, Geoffrey E. Hinton (2012)
# *ImageNet Classification with Deep Convolutional Neural Networks*
# [Link](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf)
#
# Matthew D Zeiler, Rob Fergus (2013)
# *Visualizing and Understanding Convolutional Networks*
# [Link](https://arxiv.org/abs/1311.2901)
#
# **The Adam Optimizer**
# Diederik P. Kingma, Jimmy Ba (2014)
# *Adam: A Method for Stochastic Optimization*
# [Link](https://arxiv.org/abs/1412.6980)
#
# **Inception and ResNet**
# Min Lin, Qiang Chen, Shuicheng Yan (2014)
# *Network in Network*
# [Link](https://arxiv.org/pdf/1312.4400v3.pdf)
#
# Christian Szegedy, Wei Liu, Yangqing Jia, Pierre Sermanet, Scott Reed, Dragomir Anguelov, Dumitru Erhan, Vincent Vanhoucke, Andrew Rabinovich (2014)
# *Going deeper with convolutions*
# [Link](https://arxiv.org/abs/1409.4842)
#
# Christian Szegedy, Vincent Vanhoucke, Sergey Ioffe, Jonathon Shlens, Zbigniew Wojna (2015)
# *Rethinking the Inception Architecture for Computer Vision*
# [Link](https://arxiv.org/abs/1512.00567)
#
# Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun (2015)
# *Deep Residual Learning for Image Recognition*
# [Link](https://arxiv.org/abs/1512.03385)
#
# Christian Szegedy, Sergey Ioffe, Vincent Vanhoucke, Alex Alemi (2016)
# *Inception-v4, Inception-ResNet and the Impact of Residual Connections on Learning*
# [Link](https://arxiv.org/abs/1602.07261)
#
# François Chollet (2016)
# *Xception: Deep Learning with Depthwise Separable Convolutions*
# [Link](https://arxiv.org/abs/1610.02357)
#
# **Google AutoML and NASNET**
# Barret Zoph, Vijay Vasudevan, Jonathon Shlens, Quoc V. Le (2017)
# *Learning Transferable Architectures for Scalable Image Recognition*
# [Link](https://arxiv.org/abs/1707.07012)
#
# Chenxi Liu, Barret Zoph, Maxim Neumann, Jonathon Shlens, Wei Hua, Li-Jia Li, Li Fei-Fei, Alan Yuille, Jonathan Huang, Kevin Murph (2017)
# *Progressive Neural Architecture Search*
# [Link](https://arxiv.org/abs/1712.00559v3)
#
# **Data Augmentation**
# Ekin D. Cubuk, Barret Zoph, Jonathon Shlens, Quoc V. Le (2019)
# *RandAugment: Practical automated data augmentation with a reduced search space*
# [Link](https://arxiv.org/abs/1909.13719v2)
#
# **MobileNet**
# Andrew G. Howard, Menglong Zhu, Bo Chen, Dmitry Kalenichenko, Weijun Wang, Tobias Weyand, Marco Andreetto, Hartwig Adam (2017)
# *MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications*
# [Link](https://arxiv.org/abs/1704.04861)
#
# Mark Sandler, Andrew Howard, Menglong Zhu, Andrey Zhmoginov, Liang-Chieh Chen (2018)
# *MobileNetV2: Inverted Residuals and Linear Bottlenecks*
# [Link](https://arxiv.org/abs/1801.04381v4)
#
# Andrew Howard, Mark Sandler, Grace Chu, Liang-Chieh Chen, Bo Chen, Mingxing Tan, Weijun Wang, Yukun Zhu, Ruoming Pang, Vijay Vasudevan, Quoc V. Le, Hartwig Adam (2019)
# *Searching for MobileNetV3*
# [Link](https://arxiv.org/abs/1905.02244v5)
#
# **Loss Landscapes**
# Hao Li, Zheng Xu, Gavin Taylor, Christoph Studer, Tom Goldstein (2018)
# *Visualizing the Loss Landscape of Neural Nets*
# [Link](https://arxiv.org/abs/1712.09913)
#
# **GANs**
# Ian J. Goodfellow, Jean Pouget-Abadie, Mehdi Mirza, Bing Xu, David Warde-Farley, Sherjil Ozair, Aaron Courville, Yoshua Bengio (2014)
# *Generative Adversarial Networks*
# [Link](https://arxiv.org/abs/1406.2661)
#
# Alec Radford, Luke Metz, Soumith Chintala (2016)
# *Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks*
# [Link](https://arxiv.org/abs/1511.06434)
#
# **Batch Normalization**
# Sergey Ioffe, Christian Szegedy (2015)
# *Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift*
# [Link](https://arxiv.org/abs/1502.03167)
#
# **Word2vec**
# Tomas Mikolov, Ilya Sutskever, Kai Chen, Greg Corrado, Jeffrey Dean (2013)
# *Distributed Representations of Words and Phrases and their Compositionality*
# [Link](https://arxiv.org/abs/1310.4546)
#
# **RNNs and LSTMs**
# Andrej Karpathy, Justin Johnson, Li Fei-Fei (2015)
# *Visualizing and Understanding Recurrent Networks*
# [Link](https://arxiv.org/abs/1506.02078)
#
# Klaus Greff, Rupesh Kumar Srivastava, Jan Koutník, Bas R. Steunebrink, Jürgen Schmidhuber (2015)
# *LSTM: A Search Space Odyssey*
# [Link](https://arxiv.org/abs/1503.04069)
#
# Rahul Dey, Fathi M. Salem (2017)
# *Gate-Variants of Gated Recurrent Unit (GRU) Neural Networks*
# [Link](https://arxiv.org/abs/1701.05923)
#
# **Object Detection**
# Ross Girshick, Jeff Donahue, Trevor Darrell, Jitendra Malik (2014)
# *Rich feature hierarchies for accurate object detection and semantic segmentation*
# [Link](https://arxiv.org/abs/1311.2524)
#
# Ross Girshick (2015)
# *Fast R-CNN*
# [Link](https://arxiv.org/abs/1504.08083)
#
# Shaoqing Ren, Kaiming He, Ross Girshick, Jian Sun (2016)
# *Faster R-CNN: Towards Real-Time Object Detection with Region Proposal Networks*
# [Link](https://arxiv.org/abs/1506.01497)
#
# Kaiming He, Georgia Gkioxari, Piotr Dollár, Ross Girshick (2018)
# *Mask R-CNN*
# [Link](https://arxiv.org/abs/1703.06870)
#
# Wei Liu, Dragomir Anguelov, Dumitru Erhan, Christian Szegedy, Scott Reed, Cheng-Yang Fu, Alexander C. Berg (2016)
# *SSD: Single Shot MultiBox Detector*
# [Link](https://arxiv.org/abs/1512.02325)
#
# Joseph Redmon, Ali Farhadi (2016)
# *YOLO9000: Better, Faster, Stronger*
# [Link](https://arxiv.org/abs/1612.08242)
#
#
# Joseph Redmon, Santosh Divvala, Ross Girshick, Ali Farhadi (2016)
#
# *You Only Look Once: Unified, Real-Time Object Detection*
# [Link](https://arxiv.org/abs/1506.02640)
#
# **Fully Convolutional Networks**
# Jost Tobias Springenberg, Alexey Dosovitskiy, Thomas Brox, Martin Riedmiller (2015)
# *Striving for Simplicity: The All Convolutional Net*
# [Link](https://arxiv.org/abs/1412.6806)
#
# Evan Shelhamer, Jonathan Long, Trevor Darrell (2016)
# *Fully Convolutional Networks for Semantic Segmentation*
# [Link](https://arxiv.org/abs/1605.06211)
#
# Forrest N. Iandola, Song Han2, Matthew W. Moskewicz, Khalid Ashraf, William J. Dally, Kurt Keutzer (2016)
# SqueezeNet: AlexNet-Level Accuracy with 50X Fewer Parameters and less than 0.5MB Model Size
# [Link](https://arxiv.org/abs/1602.07360)
#
# **Pruning and Quantization**
# Song Han, Huizi Mao, William J. Dally (2015)
# *Deep Compression: Compressing Deep Neural Networks with Pruning, Trained Quantization and Huffman Coding*
# [Link](https://arxiv.org/abs/1510.00149v3)
#
# Darryl D. Lin, Sachin S. Talathi, V. Sreekanth Annapureddy (2016)
# *Fixed Point Quantization of Deep Convolutional Networks*
# [Link](https://arxiv.org/abs/1511.06393)
#
# Itay Hubara, Matthieu Courbariaux, Daniel Soudry, Ran El-Yaniv, Yoshua Bengio (2016)
# *Quantized Neural Networks: Training Neural Networks with Low Precision Weights and Activations*
# [Link](https://arxiv.org/abs/1609.07061)
#
# Philipp Gysel (2016)
# *Ristretto: Hardware-Oriented Approximation of Convolutional Neural Networks*
# [Link](https://arxiv.org/abs/1605.06402)
#
# **TensorFlow**
# Peter Goldsborough (2016)
# *A Tour of TensorFlow*
# [Link](https://arxiv.org/abs/1610.01178)
#
# **Transformer and Large Language Models**
#
# Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin (2017)
# *Attention Is All You Need*
# [Link](https://arxiv.org/abs/1706.03762)
#
# Edward J. Hu, Yelong Shen, Phillip Wallis, Zeyuan Allen-Zhu, Yuanzhi Li, Shean Wang, Lu Wang, Weizhu Chen
# *LoRA: Low-Rank Adaptation of Large Language Models*
# [Link](https://arxiv.org/abs/2106.09685)
#
# Hugo Touvron, Thibaut Lavril, Gautier Izacard, Xavier Martinet et al (2023)
# *LLaMA: Open and Efficient Foundation Language Models*
# [Link](https://arxiv.org/abs/2302.13971)
#
# Gemma Team: Aishwarya Kamath, Johan Ferret, Shreya Pathak et al. (2025)
# *Gemma 3 Technical Report*
# [Link](https://arxiv.org/abs/2503.19786)
#
# Luca Soldaini, Rodney Kinney, Akshita Bhagia, Dustin Schwen et al (2024)
# *Dolma: an Open Corpus of Three Trillion Tokens for Language Model Pretraining Research*
# [Link](https://arxiv.org/abs/2402.00159)

# %% [markdown]
# ## Blogs
#
# **Tutorial from SciPy 2016** - Scientific Computing with Python
# A comprehensive description of how to use **scikit-learn** for machine learning (but not deep learning)
# Sebastian Raschka, Andreas Mueller
# [Video Part 1](https://youtu.be/OB1reY6IX-o)
# [Video Part 2](https://youtu.be/Cte8FYCpylk)
#
# **Machine Learning Mastery**
# A comprehensive blog/e-book
# Jason Brownlee
# [Link](https://machinelearningmastery.com/)
#
# **deeplearning.net**
# Blog containing a collection of deep learning resources
# [Link](http://deeplearning.net/)
#
# **Adventures in Machine Learning**
# Tutorials and articles on machine learning by Andy Thomas
# [Link](http://adventuresinmachinelearning.com/)
#
# **WILDML**
# A blog on AI and deep learning
# Denny Britz
# [Link](http://www.wildml.com/)
#
# **Deep Learning Sandbox**
# A blog on open source deep learning tools
# [Link](https://deeplearningsandbox.com/)
#
# **Towards Data Science**
# A blog on data science and machine learning
# [Link](https://towardsdatascience.com/)
#
# **Andrej Karpathy's Blog**
# [Hackers Guide to Neural Networks](http://karpathy.github.io/neuralnets/)
# [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# **Dhruv Parthasarathy's Blog**
# [A Brief History of CNNs in Image Segmentation: From R-CNN to Mask R-CNN](https://blog.athelas.com/a-brief-history-of-cnns-in-image-segmentation-from-r-cnn-to-mask-r-cnn-34ea83205de4)
#
# **Pete Warden's Blog**
# [What I’ve learned about neural network quantization](https://petewarden.com/2017/06/22/what-ive-learned-about-neural-network-quantization/)
#
# **Visualizing Loss Landscapes**
# Some stunning videos
# [Exploring the Landscape](https://losslandscape.com/)
#
# **Gradient Descent**
# A nice tutorial
# [Intro to optimization in deep learning: Gradient Descent](https://blog.paperspace.com/intro-to-optimization-in-deep-learning-gradient-descent/)
#
# Some really nice animations including escape from saddle points
# [Deniz Yuret's blog](http://www.denizyuret.com/2015/03/alec-radfords-animations-for.html)
#
# **CNNs**
# Nice animiations of the various kinds of convolution
# [Convolution Arithmetic](https://github.com/vdumoulin/conv_arithmetic)
#
# **Google AutoML**
# [Google AI Blog](https://ai.googleblog.com/2017/11/automl-for-large-scale-image.html)
#
# **ImageNet State-of-the-art**
# An up-to-date list of the state-of-the-art methods, with links to the papers
# [Image Classification on ImageNet](https://paperswithcode.com/sota/image-classification-on-imagenet)
#
# **One-shot object detection**
# A great description of SSD and YOLO
# [One-shot object detection](https://machinethink.net/blog/object-detection/)
#
# **LSTMs**
# [colah's blog - Understanding LSTM Networks](http://colah.github.io/posts/2015-08-Understanding-LSTMs/)
# [A Beginners Guide to Recurrent Networks and LSTMs](https://deeplearning4j.org/lstm.html#a-beginners-guide-to-recurrent-networks-and-lstms)
#
# **Natural Language Processing / Word Embedding**
# [Deep Learning, NLP, and Representations](http://colah.github.io/posts/2014-07-NLP-RNNs-Representations/)
# [A Word2Vec Keras tutorial](http://adventuresinmachinelearning.com/word2vec-keras-tutorial/)
#
# **The COCO Dataset**
# [COCO](http://cocodataset.org)
# [COCO + Places 2017](https://places-coco2017.github.io/)
#
# **Distill**
# A really well-presented web site with some fascinating content.
# [Home page](https://distill.pub/)
# [Why Momentum Really Works](https://distill.pub/2017/momentum/)
# [How to Use t-SNE Effectively](https://distill.pub/2016/misread-tsne/)
# [Feature Visualization](https://distill.pub/2017/feature-visualization/)
# [The Building Blocks of Interpretability](https://distill.pub/2018/building-blocks/)
#
#
# ## TensorFlow and Keras
#
# **TensorFlow and Deep Learning without a PhD**
# Martin Görner
# A comprehensive YouTube video tutorial with a particularly good discussion of dropout, batch normalization, and RNNs.
# [Link](https://www.youtube.com/watch?v=vq2nnJ4g6N0)
#
# **TensorFlow tutorials**
# [Link](https://www.tensorflow.org/tutorials/)
#
# **Keras documentation**
# [Link](https://keras.io/)
#
# **Keras blog**
# [Link](https://blog.keras.io/)
#
# **TensorFlow Playground**
# Play with a neural network in your web browser
# [Link](https://playground.tensorflow.org/)
